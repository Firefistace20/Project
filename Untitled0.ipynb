# %% [markdown]
# <a href="https://colab.research.google.com/github/Firefistace20/Project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import os

# %%
# Load and preprocess data
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
class_names = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
]

# %%
# prompt: horse dog deer

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import os
# Load and preprocess data
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
class_names = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
]

# Find indices where labels match "horse", "dog", or "deer"
horse_indices = [i for i, label in enumerate(train_labels) if label == 7]  # Horse label is 7
dog_indices = [i for i, label in enumerate(train_labels) if label == 5]  # Dog label is 5
deer_indices = [i for i, label in enumerate(train_labels) if label == 4]  # Deer label is 4


# Combine the indices
combined_indices = horse_indices + dog_indices + deer_indices


# Get the images and labels corresponding to the combined indices
selected_images = train_images[combined_indices]
selected_labels = train_labels[combined_indices]

print(len(selected_images))
print(len(selected_labels))
# Out:
# 15000
# 15000

# %%
def classify_image(image):
    img_array = tf.expand_dims(image, 0)  # Create a batch
    predictions = model.predict(img_array)
    predicted_class = tf.argmax(predictions[0]).numpy()
    return class_names[predicted_class]


# Display the image with its predicted class
def show_image_with_prediction(image, true_label):
    predicted_label = classify_image(image)
    plt.figure()
    plt.imshow(image)
    plt.title(f"Predicted: {predicted_label}, True: {true_label}")
    plt.axis("off")
    plt.show()

# %%
# Function to classify and display a single image
def show_single_image_with_prediction(image, true_label_index):
    predicted_label = classify_image(image)
    true_label = class_names[true_label_index]
    plt.figure()
    plt.imshow(image)
    plt.title(f"Predicted: {predicted_label}, True: {true_label}")
    plt.axis("off")
    plt.show()

# Loop to ask for image index and display the corresponding image
while True:
    try:
        index = int(input("Enter the index of the image you want to classify (0 to 9999): "))
        if 0 <= index < len(test_images):
            show_single_image_with_prediction(test_images[index], test_labels[index][0])
        else:
            print("Index out of range. Please enter a number between 0 and 9999.")
    except ValueError:
        print("Invalid input. Please enter a valid number.")
    except KeyboardInterrupt:
        print("\nExiting the interactive image display.")
        break
# Out:
# Enter the index of the image you want to classify (0 to 9999): 6 10 56
# Invalid input. Please enter a valid number.
# Enter the index of the image you want to classify (0 to 9999): 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Enter the index of the image you want to classify (0 to 9999): 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Enter the index of the image you want to classify (0 to 9999): 90
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Enter the index of the image you want to classify (0 to 9999): 300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Exiting the interactive image display.
